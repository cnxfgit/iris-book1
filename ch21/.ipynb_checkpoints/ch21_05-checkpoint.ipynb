# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
date_range = pd.date_range(start="2023-01-01",
                          periods=365*2, freq='D')

# %%
df = pd.DataFrame(index=date_range)

# %%
num_path = 50

# %%
np.random.seed(0)

# %%
for i in range(num_path):
    step_idx = np.random.normal(loc=0.0, scale=1.0,
                               size=len(date_range) - 1)
    step_idx = np.append(0, step_idx)

    walk_idx = step_idx.cumsum()
    df[f'Walk_{i + 1}'] = walk_idx

# %%
df.plot(legend=False)
plt.grid(True)
plt.ylim(-80, 80)
# Out:
# (-80.0, 80.0)

# %%
df[['Walk_1', 'Walk_2']].plot(legend=True)
plt.grid(True)
plt.ylim(-80, 80)
# Out:
# (-80.0, 80.0)

# %%
df.loc['2023-01-01': '2023-08-08',
    ['Walk_1', 'Walk_2']].plot(legend=True)
plt.grid(True)
plt.ylim(-80, -80)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_213148\327467498.py:4: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   plt.ylim(-80, -80)
# (-84.0, -76.0)
